# %% [markdown]
# ## Markers
#
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %% [markdown]
# Example
#
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a star:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a point:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '.')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a pixel:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = ',')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with an X:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'x')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with an X (filled):

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'X')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a plus:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '+')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a plus (filled):

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'P')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a square:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 's')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a diamond:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'D')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a diamond (thin):

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'd')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a pentagon:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'p')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a hexagon:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'H')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a triangle down:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'v')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a triangle up:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '^')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a triangle right:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '>')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a triangle left:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '<')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a tri down:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '1')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a tri up:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '2')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a tri left:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '3')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a tri right:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '4')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a Vline:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '|')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a Hline:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '_')
plt.show()

# %% [markdown]
# ## Format Strings fmt
#
# You can use also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %% [markdown]
# Example
#
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a solid line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '-')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a dotted line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, ':')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a dashed line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '--')
plt.show()

# %% [markdown]
# Example
#
# Mark each point with a dashed/dotted line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '-.')
plt.show()

# %% [markdown]
# #### Note: If you leave out the line value in the fmt parameter, no line will be plottet.

# %% [markdown]
# ## The short color value can be one of the following:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'c')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'm')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'w') # white
plt.show()

# %% [markdown]
# ## Marker Size
#
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers:

# %% [markdown]
# Example
#
# Set the size of the markers to 20:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# ## Marker Color
#
# You can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# You can use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

# %% [markdown]
# Example
#
# Set the FACE color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# Use both the mec and mfc arguments to color of the entire marker:

# %% [markdown]
# Example
#
# Set the color of both the edge and the face to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %% [markdown]
# You can also use Hexadecimal color values:

# %% [markdown]
# Example
#
# Mark each point with a beautiful green color:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %% [markdown]
# Or any of the 140 supported color names.

# %% [markdown]
# Example
#
# Mark each point with the color named "hotpink":

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()
